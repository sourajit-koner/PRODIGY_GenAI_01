# %%
# !pip install -q transformers datasets accelerate torch

# %% [markdown]
# # New Section

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

model_name = "gpt2"

tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

print("GPT-2 loaded successfully!")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT-2 loaded successfully!

# %%
import transformers
print(f"Transformers version: {transformers.__version__}")
# Out:
# Transformers version: 5.15.0

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

model_name = "gpt2"

tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

print("GPT-2 loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT-2 loaded successfully!

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset(
    "text",
    data_files={"train": "ai_dataset.txt"}
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 300
#     })
# })

# %%
print(dataset["train"][0])
# Out:
# {'text': 'Artificial intelligence enables computers to perform tasks that normally require human intelligence.'}

# %%
print(dataset["train"][:5])
# Out:
# {'text': ['Artificial intelligence enables computers to perform tasks that normally require human intelligence.', 'AI systems can analyze information and produce useful predictions or decisions.', 'Artificial intelligence is used in education, healthcare, finance, transportation, and entertainment.', 'AI can help organizations automate repetitive tasks and improve productivity.', 'Modern AI combines algorithms, data, and computing resources to solve complex problems.']}

# %%
from datasets import load_dataset

dataset = load_dataset(
    "text",
    data_files={"train": "ai_dataset.txt"}
)

print(dataset)

print(dataset["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 300
#     })
# })
# {'text': 'Artificial intelligence enables computers to perform tasks that normally require human intelligence.'}

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding="max_length",
        max_length=128
    )

tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=["text"]
)

print("Dataset tokenized successfully!")
# Out:
# Map:   0%|          | 0/300 [00:00<?, ? examples/s]
# Dataset tokenized successfully!

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# %%
# !pip install -U transformers datasets accelerate

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

model_name = "gpt2"

tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

print("GPT-2 loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT-2 loaded successfully!

# %%
print(f"Tokenizer vocabulary size: {tokenizer.vocab_size}")
print(f"Tokenizer special tokens map: {tokenizer.special_tokens_map}")
print(f"All special tokens: {tokenizer.all_special_tokens}")
# Out:
# Tokenizer vocabulary size: 50257
# Tokenizer special tokens map: {'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>', 'pad_token': '<|endoftext|>'}
# All special tokens: ['<|endoftext|>']

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding="max_length",
        max_length=128
    )

tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=["text"]
)

print("Dataset tokenized successfully!")
# Out:
# Dataset tokenized successfully!

# %%
from datasets import load_dataset

dataset = load_dataset(
    "text",
    data_files={"train": "ai_dataset.txt"}
)
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 300
#     })
# })

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding="max_length",
        max_length=128
    )

tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=["text"]
)

print("Dataset tokenized successfully!")
# Out:
# Dataset tokenized successfully!

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./gpt2-ai-model",
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=2,
    logging_steps=50,
    learning_rate=5e-5,
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    data_collator=data_collator
)

trainer.train()
# Out:
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='450' max='450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [450/450 00:55, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>3.708648</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.951964</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.598607</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.765901</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.831467</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.752007</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.413708</td>
#     </tr>
#     <tr>
#       <td>400</td>
# ...

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./gpt2-ai-model",
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=2,
    logging_steps=50,
    learning_rate=5e-5,
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    data_collator=data_collator
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='450' max='450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [450/450 01:08, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.099310</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.087691</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.099794</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.631021</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.751419</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.785517</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.621660</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.637179</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.766589</td>
#     </tr>
#   </tbody>
# ...

# %%
import transformers
import torch

print(f"Transformers version: {transformers.__version__}")
print(f"PyTorch version: {torch.__version__}")
# Out:
# Transformers version: 5.15.0
# PyTorch version: 2.11.0+cu128

# %%
trainer.save_model("./gpt2-ai-model")
tokenizer.save_pretrained("./gpt2-ai-model")

print("Model saved successfully!")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved successfully!

# %%
from transformers import pipeline, GenerationConfig, GPT2LMHeadModel, GPT2Tokenizer

# 1. Load the model and tokenizer first
model_name_or_path = "./gpt2-ai-model"
tokenizer = GPT2Tokenizer.from_pretrained(model_name_or_path)
model = GPT2LMHeadModel.from_pretrained(model_name_or_path)

# Ensure pad_token is set for the tokenizer and model for consistent generation
tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

# 2. Load the generation configuration from the model path
gen_config = GenerationConfig.from_pretrained(model_name_or_path)

# 3. Explicitly set or override the desired generation parameters on this config object
gen_config.max_new_tokens = 100
gen_config.temperature = 0.8
gen_config.top_k = 50
gen_config.top_p = 0.95
# Set max_length to be consistent with max_new_tokens (or greater, as a hard limit)
gen_config.max_length = gen_config.max_new_tokens # Or a larger value like 150 if needed

# 4. Assign the modified generation config directly to the model
model.generation_config = gen_config

# 5. Initialize the pipeline using the pre-configured model and tokenizer objects
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

prompt = "Artificial intelligence"

# The subsequent call only needs to specify num_return_sequences, or other dynamic parameters
result = generator(
    prompt,
    num_return_sequences=1
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial intelligence projects benefit from clear documentation and reproducible experiments. Papers and videos explain how an AI system works and explain technical concepts. Popular videos explain technical concepts and avoid technical jargon.
#
# Machine learning models are most effective when their strengths and limitations are understood. AI systems can learn from examples rather than from rules or assumptions. AI systems can learn from examples rather than from rules or assumptions. Learning algorithms can learn from examples rather than from rules or assumptions.
#
# Machine learning models can learn many useful patterns from

# %%
trainer.save_model("./gpt2-ai-model")
tokenizer.save_pretrained("./gpt2-ai-model")

print("Final model saved successfully!")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Final model saved successfully!

# %%
result = generator(
    prompt,
    max_new_tokens=100,
    num_return_sequences=1,
    temperature=0.8,
    top_k=50,
    top_p=0.95
)
# Out:
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
prompts = [
    "Artificial intelligence",
    "Machine learning",
    "Deep learning",
    "Generative AI",
    "Python and artificial intelligence"
]

for prompt in prompts:
    print("\n" + "=" * 60)
    print("PROMPT:", prompt)
    print("=" * 60)

    result = generator(
        prompt,
        num_return_sequences=1 # Rely on pipeline's default generation parameters
    )

    print(result[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
# PROMPT: Artificial intelligence
# ...
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
